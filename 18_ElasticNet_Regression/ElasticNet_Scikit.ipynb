# %% [markdown]
# # **Regularization (L1 + L2):** ElasticNet Regression (**Scikit**)

# %%
from IPython.display import Image
Image(filename='ElasticNet_Cost.png')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes

data=load_diabetes()

# %%
print(data.DESCR)

# %%
from sklearn.model_selection import train_test_split

X = data.data
y = data.target
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=45)

# %% [markdown]
# ## **OLS**

# %%
from sklearn.linear_model import LinearRegression

L = LinearRegression()
L.fit(X_train,y_train)

from sklearn.metrics import r2_score,mean_squared_error

y_pred = L.predict(X_test)
print("R2 score",r2_score(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2 score 0.5188113124539246
# RMSE 48.727137609532534

# %% [markdown]
# ## **Ridge (L2)**

# %%
from sklearn.linear_model import Ridge
R = Ridge(alpha=0.1)
R.fit(X_train,y_train)

y_pred1=R.predict(X_test)
print("R2 score",r2_score(y_test,y_pred1))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred1)))
# Out:
# R2 score 0.5208421054129915
# RMSE 48.62420568515607

# %% [markdown]
# ## **Lasso (L1)**

# %%
from sklearn.linear_model import Lasso
La = Lasso(alpha=0.1)
La.fit(X_train,y_train)

y_pred1 = La.predict(X_test)
print("R2 score", r2_score(y_test, y_pred1))
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred1)))
# Out:
# R2 score 0.535113939714094
# RMSE 47.894589779288324

# %% [markdown]
# ## **ElasticNet (L1 + L2)**

# %%
from sklearn.linear_model import ElasticNet
En = ElasticNet(alpha=0.0008, l1_ratio=0.9)
En.fit(X_train,y_train)

y_pred1 = En.predict(X_test)
print("R2 score", r2_score(y_test, y_pred1))
print("RMSE", np.sqrt(mean_squared_error(y_test, y_pred1)))
# Out:
# R2 score 0.5233990333552103
# RMSE 48.49429558753106
