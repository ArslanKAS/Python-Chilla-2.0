# %% [markdown]
# # <strong>Selenium:</strong> Web Scrapping - Fiverr
#
# **Name:** Arsalan Ali<br>
# **Email:** arslanchaos@gmail.com
#
# ---

# %% [markdown]
# ### **Table of Contents**
# * Website to Scrap: "Fiverr"
# * Link of the site: http://fiverr.com/
# * Top Logo Designers
# *
#
# ---

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.fiverr.com/categories/graphics-design/creative-logo-design?source=pagination&pos=3&name=creative-logo-design&page=1&offset=-12'

headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

webpage = requests.get(url, headers=headers).text
soup = BeautifulSoup(webpage, "lxml")

# %%
soup.find_all("div")
# Out:
# [<div id="px-captcha"></div>,
#  <div height="1" style="position:fixed; top:0; left:0;" width="1"><img src="https://collector.fiverr.com/api/v1/collector/noScript.gif?appId=PXK3bezZfO"/></div>,
#  <div height="1" style="position:fixed; top:0; left:0;" width="1"><img src="https://collector.fiverr.com/api/v1/collector/pxPixel.gif?appId=PXK3bezZfO"/></div>]

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <meta content="no-cache" http-equiv="Cache-Control"/>\n  <link href="data:image/x-icon;base64,..." rel="shortcut icon"/>\n  <meta content="noindex" name="googlebot"/>\n  <meta content="noindex" name="robots"/>\n  <title>\n   Your Access To This Website Has Been Blocked\n  </title>\n  <style>\n   html {\n    -webkit-font-smoothing: antialiased;\n    -moz-osx-font-smoothing: grayscale;\n    height: 100%;\n}\n\n* {\n    margin: 0;\n    padding: 0;\n    border: 0;\n    outline: 0;\n    font-size: 100%;\n    vertical-align: baseline;\n    background: transparent;\n}\n\narticle, aside, figure, footer, header, hgroup, nav, section { display: block; }\n\nul, ol, nav ul, nav ol {\n    list-style: none;\n    list-style-image: none;\n}\nbody {\n    background: #fff;\n    font: 400
# ...
