# %% [markdown]
# # **Lazy Predict:** Collection of Multiple ML Algos

# %% [markdown]
# ## **Supervised:** Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  fare embarked  class    who  \
# 0         0       3    male 22.00      1      0  7.25        S  Third    man
# 1         1       1  female 38.00      1      0 71.28        C  First  woman
# 2         1       3  female 26.00      0      0  7.92        S  Third  woman
# 3         1       1  female 35.00      1      0 53.10        S  First  woman
# 4         0       3    male 35.00      0      0  8.05        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
df = df[["survived", "pclass", "age", "fare"]]

# %%
X = df.drop("fare", axis=1)
y = df["fare"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
reg = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None )
models,predictions = reg.fit(X_train, X_test, y_train, y_test)

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared    RMSE  \
# Model
# PoissonRegressor                             0.43       0.44   34.30
# MLPRegressor                                 0.39       0.40   35.51
# LarsCV                                       0.39       0.40   35.64
# Lars                                         0.39       0.40   35.64
# LassoLarsIC                                  0.39       0.40   35.64
# LassoLarsCV                                  0.39       0.40   35.64
# OrthogonalMatchingPursuitCV                  0.39       0.40   35.64
# LinearRegression                             0.39       0.40   35.64
# TransformedTargetRegressor                   0.39       0.40   35.64
# Ridge                                        0.39       0.40   35.65
# SGDRegressor                                 0.39       0.40   35.65
# LassoCV                                      0.39       0.40   35.65
# ...

# %% [markdown]
# ### Top 5 Models that performed well

# %%
models.nlargest(5,"R-Squared")
# Out:
#                   Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# PoissonRegressor                0.43       0.44 34.30        0.05
# MLPRegressor                    0.39       0.40 35.51        1.00
# LarsCV                          0.39       0.40 35.64        0.05
# Lars                            0.39       0.40 35.64        0.02
# LassoLarsIC                     0.39       0.40 35.64        0.03

# %% [markdown]
# ---

# %% [markdown]
# ## **Supervised:** Classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  fare embarked  class    who  \
# 0         0       3    male 22.00      1      0  7.25        S  Third    man
# 1         1       1  female 38.00      1      0 71.28        C  First  woman
# 2         1       3  female 26.00      0      0  7.92        S  Third  woman
# 3         1       1  female 35.00      1      0 53.10        S  First  woman
# 4         0       3    male 35.00      0      0  8.05        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
df = df[["survived", "pclass", "sex", "age", "class", "who"]]

# %%
X = df.drop("survived", axis=1)
y = df["survived"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.82               0.83     0.83      0.82
# LabelSpreading                     0.82               0.81     0.81      0.82
# LabelPropagation                   0.82               0.80     0.80      0.82
# LinearSVC                          0.81               0.80     0.80      0.81
# RidgeClassifierCV                  0.81               0.80     0.80      0.81
# CalibratedClassifierCV             0.81               0.80     0.80      0.81
# RidgeClassifier                    0.81               0.80     0.80      0.81
# LinearDiscriminantAnalysis         0.81               0.80     0.80      0.81
# KNeighborsClassifier               0.82               0.80     0.80      0.81
# LGBMClassifier                     0.82               0.80     0.80      0.81
# GaussianNB                         0.81               0.80     0.80      0.81
# ...

# %% [markdown]
# ### Top 5 Models that performed well

# %%
models.nlargest(5,"Accuracy")
# Out:
#                       Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LabelSpreading            0.82               0.81     0.81      0.82
# NearestCentroid           0.82               0.83     0.83      0.82
# LabelPropagation          0.82               0.80     0.80      0.82
# KNeighborsClassifier      0.82               0.80     0.80      0.81
# LGBMClassifier            0.82               0.80     0.80      0.81
#
#                       Time Taken
# Model
# LabelSpreading              0.06
# NearestCentroid             0.03
# LabelPropagation            0.06
# KNeighborsClassifier        0.07
# LGBMClassifier              0.15
